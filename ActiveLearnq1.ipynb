# %% [markdown]
# QUESTION 01:

# %% [markdown]
# Q1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv') #Iris dataset loaded

# %%
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# HISTOGRAM

# %%
for col in iris.columns:
    # Histogram
    iris[col].hist()
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.title(f"Histogram of {col}")
    plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
 # Scatter plots (against other columns)
for col in iris.columns:
   for other_col in iris.columns:
      if col != other_col:
            plt.scatter(iris[col], iris[other_col],alpha=0.5,s=8)
            plt.xlabel(col)
            plt.ylabel(other_col)
            plt.title(f"Scatter plot of {col} vs. {other_col}")
            plt.show()

# %% [markdown]
# Q2

# %%
numerical_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

for column in numerical_columns:
    column_data = iris[column]
    mean_value = column_data.mean()
    median_value = column_data.median()
    mode_value = column_data.iloc[0]
    std_dev_value = column_data.std()

    print(f"\nStatistics for {column}:")
    print(f"Mean: {mean_value}")
    print(f"Median: {median_value}")
    print(f"Mode: {mode_value}")
    print(f"Standard Deviation: {std_dev_value}\n")
# Out:
# Statistics for sepal_length:
# Mean: 5.843333333333334
# Median: 5.8
# Mode: 5.1
# Standard Deviation: 0.828066127977863
#
#
# Statistics for sepal_width:
# Mean: 3.0540000000000003
# Median: 3.0
# Mode: 3.5
# Standard Deviation: 0.4335943113621737
#
#
# Statistics for petal_length:
# Mean: 3.758666666666666
# Median: 4.35
# Mode: 1.4
# Standard Deviation: 1.7644204199522626
#
#
# Statistics for petal_width:
# Mean: 1.1986666666666668
# Median: 1.3
# Mode: 0.2
# Standard Deviation: 0.7631607417008411
